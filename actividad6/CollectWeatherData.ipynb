# %%
pip install requests pandas numpy
# Out:
# Requirement already satisfied: requests in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.32.3)
# Collecting pandas
#   Downloading pandas-2.3.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.3.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.9 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 649.9 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\fran_\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.3 MB 2.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/11.3 MB 4.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.3 MB 5.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.3 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.3 MB 10.2 MB/s eta 0:00:01
#    --------- ------------------------------ 2.7/11.3 MB 10.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.3 MB 12.4 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.3 MB 13.3 MB/s eta 0:00:01
#    ------------------ --------------------- 5.2/11.3 MB 13.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.7/11.3 MB 13.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.3 MB 14.4 MB/s eta 0:00:01
#    --------------------------- ------------ 7.7/11.3 MB 14.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.0/11.3 MB 15.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.6/11.3 MB 14.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.3 MB 14.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 14.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.3 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 16.4 MB/s eta 0:00:00
# Downloading numpy-2.3.3-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    - -------------------------------------- 0.4/13.1 MB 9.2 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/13.1 MB 10.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/13.1 MB 13.5 MB/s eta 0:00:01
#    ------- -------------------------------- 2.3/13.1 MB 13.5 MB/s eta 0:00:01
#    --------- ------------------------------ 3.1/13.1 MB 14.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.8/13.1 MB 15.3 MB/s eta 0:00:01
#    ------------- -------------------------- 4.5/13.1 MB 15.8 MB/s eta 0:00:01
#    --------------- ------------------------ 5.1/13.1 MB 15.5 MB/s eta 0:00:01
#    ------------------ --------------------- 5.9/13.1 MB 15.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.8/13.1 MB 16.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.5/13.1 MB 16.0 MB/s eta 0:00:01
#    ------------------------- -------------- 8.3/13.1 MB 16.6 MB/s eta 0:00:01
#    --------------------------- ------------ 9.2/13.1 MB 16.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/13.1 MB 16.3 MB/s eta 0:00:01
#    ------------------------------- -------- 10.4/13.1 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.4/13.1 MB 17.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.1 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 16.8 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.3.3 pandas-2.3.2 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\fran_\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd
import numpy as np
from keys import *

# Ciudad seleccionada | Ciudad de Mexico, MX
# Pais | Mexico
city = "Ciudad de Mexico"
country = "MX"

# Llama a la API de OpenWeatherMap
response = requests.get(f'http://api.openweathermap.org/data/2.5/forecast/?q={city},{country}&appid={OWM_key}&units=metric&lang=en')

# %%
data = response.json()

print(data)
print(" ")
print ("---")
print(" ")

# Genera una nueva lista con los datos del pronóstico
forecast_list = data.get('list', [])

# Crae listas para cada columna
times = []
temperatures = []
humidities = []
weather_statuses = []
wind_speeds = []
rain_volumes = []
snow_volumes = []

# Extrae los datos de cada entrada en la lista de pronósticos
for entry in forecast_list:
    times.append(entry.get('dt_txt', np.nan))
    temperatures.append(entry.get('main', {}).get('temp', np.nan))
    humidities.append(entry.get('main', {}).get('humidity', np.nan))
    weather_statuses.append(entry.get('weather', [{}])[0].get('main', np.nan))
    wind_speeds.append(entry.get('wind', {}).get('speed', np.nan))
    rain_volumes.append(entry.get('rain', {}).get('3h', np.nan))
    snow_volumes.append(entry.get('snow', {}).get('3h', np.nan))

# Crea un DataFrame de pandas con los datos extraídos
df = pd.DataFrame({
    'time': times,
    'temperature': temperatures,
    'humidity': humidities,
    'weather_status': weather_statuses,
    'wind_speed': wind_speeds,
    'rain_volume_3h': rain_volumes,
    'snow_volume_3h': snow_volumes
})

print(df.head())
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1758996000, 'main': {'temp': 20.9, 'feels_like': 20.48, 'temp_min': 20.9, 'temp_max': 22.76, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 764, 'humidity': 55, 'temp_kf': -1.86}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 73}, 'wind': {'speed': 2.46, 'deg': 38, 'gust': 2.5}, 'visibility': 10000, 'pop': 0.01, 'sys': {'pod': 'd'}, 'dt_txt': '2025-09-27 18:00:00'}, {'dt': 1759006800, 'main': {'temp': 23.37, 'feels_like': 22.89, 'temp_min': 23.37, 'temp_max': 25.07, 'pressure': 1011, 'sea_level': 1011, 'grnd_level': 761, 'humidity': 43, 'temp_kf': -1.7}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 46}, 'wind': {'speed': 3.19, 'deg': 16, 'gust': 2.59}, 'visibility': 10000, 'pop': 0.38, 'sys': {'pod': 'd'}, 'dt_txt': '2025-09-27 21:00:00'}, {'dt': 1759017600, 'main': {'temp': 20.59, 'feels_like': 20.22, 'temp_min': 20.59, 'temp_max': 20.59, 'pressure': 1012, 'sea_level': 1012, 'grnd_level': 762, 'humidity': 58, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 64}, 'wind': {'speed': 2.79, 'deg': 356, 'gust': 4.72}, 'visibility': 10000, 'pop': 0.78, 'rain': {'3h': 1.26}, 'sys': {'pod': 'd'}, 'dt_txt': '2025-09-28 00:00:00'}, {'dt': 1759028400, 'main': {'temp': 17.97, 'feels_like': 17.62, 'temp_min': 17.97, 'temp_max': 17.97, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 763, 'humidity': 69, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 82}, 'wind': {'speed': 1.1, 'deg': 4, 'gust': 1.72}, 'visibility': 6556, 'pop': 1, 'rain': {'3h': 1.74}, 'sys': {'pod': 'n'}, 'dt_txt': '2025-09-28 03:00:00'}, {'dt': 1759039200, 'main': {'temp': 15.86, 'feels_like': 15.59, 'temp_min': 15.86, 'temp_max': 15.86, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 764, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 67}, 'wind': {'speed': 1.6, 'deg': 7, 'gust': 2.5}, 'visibility': 10000, 'pop': 1, 'rain': {'3h': 2.23}, 'sys': {'pod': 'n'}, 'dt_txt': '2025-09-28 06:00:00'}, {'dt': 1759050000, 'main': {'temp': 15.14, 'feels_like': 14.93, 'temp_min': 15.14, 'temp_max': 15.14, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 764, 'humidity': 85, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 84}, 'wind': {'speed': 1.2, 'deg': 354, 'gust': 1.43}, 'visibility': 10000, 'pop': 0.93, 'rain': {'3h': 0.75}, 'sys': {'pod': 'n'}, 'dt_txt': '2025-09-28 09:00:00'}, {'dt': 1759060800, 'main': {'temp': 14.61, 'feels_like': 14.4, 'temp_min': 14.61, 'temp_max': 14.61, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 764, 'humidity': 87, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 67}, 'wind': {'speed': 0.69, 'deg': 40, 'gust': 0.9}, 'visibility': 10000, 'pop': 0.72, 'sys': {'pod': 'n'}, 'dt_txt': '2025-09-28 12:00:00'}, {'dt': 1759071600, 'main': {'temp': 17.86, 'feels_like': 17.58, 'temp_min': 17.86, 'temp_max': 17.86, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 765, 'humidity': 72, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 38}, 'wind': {'speed': 0.99, 'deg': 77, 'gust': 0.71}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-09-28 15:00:00'}, {'dt': 1759082400, 'main': {'temp': 22.39, 'feels_like': 22.02, 'temp_min': 22.39, 'temp_max': 22.39, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 764, 'humidity': 51, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'clouds': {'all': 47}, 'wind': {'speed': 1.61, 'deg': 44, 'gust': 1.27}, 'visi ...
#
# ---
#
#                   time  temperature  humidity weather_status  wind_speed  \
# 0  2025-09-27 18:00:00        20.90        55         Clouds        2.46
# 1  2025-09-27 21:00:00        23.37        43         Clouds        3.19
# 2  2025-09-28 00:00:00        20.59        58           Rain        2.79
# 3  2025-09-28 03:00:00        17.97        69           Rain        1.10
# 4  2025-09-28 06:00:00        15.86        80           Rain        1.60
#
#    rain_volume_3h  snow_volume_3h
# 0             NaN             NaN
# 1             NaN             NaN
# 2            1.26             NaN
# 3            1.74             NaN
# 4            2.23             NaN
